# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman752002/Aman752002/blob/main/BANK_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
df=pd.read_csv("bank-full.csv")
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# size of csv

# %%
df.size
# Out:
# 768587

# %% [markdown]
# information of file

# %%
df.info
# Out:
# <bound method DataFrame.info of        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# describe the file

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# drop the column that is not of use

# %%
df.drop(["previous"],axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-0cb78ed0e00e> in <module>()
# ----> 1 df.drop(["previous"],axis=1,inplace=True)
#       2 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'Target'],
#       dtype='object')

# %%
df.drop(["pdays"],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  previous poutcome Target
# 0  unknown    5   may       261         1         0  unknown     no
# 1  unknown    5   may       151         1         0  unknown     no
# 2  unknown    5   may        76         1         0  unknown     no
# 3  unknown    5   may        92         1         0  unknown     no
# 4  unknown    5   may       198         1         0  unknown     no

# %%
df.drop(columns=["poutcome","Target"],axis=1,inplace=True)

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# information

# %%
df.info
# Out:
# <bound method DataFrame.info of        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# perticular information about the pertiular column

# %%
df['age'].describe()
# Out:
# count    45211.000000
# mean        40.936210
# std         10.618762
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
df['age'] = df['age'].astype('int')

# %%
df[df['age']=='3y']
# Out:
#       age  job marital education default  balance housing loan contact  day  \
# 12739  3y  170       1        -1       0  unknown      no  NaN     NaN  NaN
#
#       month  duration  campaign
# 12739   NaN       NaN       NaN

# %%
data = df.drop(labels=(12739), axis=0,inplace=True)

# %% [markdown]
# df

# %%
df[df['age']=='3y']
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, previous]
# Index: []

# %%
df['age'] = df['age'].astype('int')

# %%
df['age'].describe()
# Out:
# count    45210.000000
# mean        40.936297
# std         10.618863
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
df['balance'] = df['balance'].astype('int')

# %%
df["balance"].describe()
# Out:
# count     45210.000000
# mean       1362.268503
# std        3044.799409
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1427.750000
# max      102127.000000
# Name: balance, dtype: float64

# %%
df['duration'] = df['duration'].astype('int')

# %%
df["duration"].describe()
# Out:
# count    45210.000000
# mean       258.161800
# std        257.530517
# min          0.000000
# 25%        103.000000
# 50%        180.000000
# 75%        319.000000
# max       4918.000000
# Name: duration, dtype: float64

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# previous     0
# dtype: int64

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45210.000000   45210.000000  45210.000000  45210.000000  45210.000000
# mean      40.936297    1362.268503     15.806614    258.161800      2.763858
# std       10.618863    3044.799409      8.322465    257.530517      3.098053
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1427.750000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#            previous
# count  45210.000000
# mean       0.580336
# std        2.303465
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      275.000000

# %%
df["duration"].describe()
# Out:
# count    45210.000000
# mean       258.161800
# std        257.530517
# min          0.000000
# 25%        103.000000
# 50%        180.000000
# 75%        319.000000
# max       4918.000000
# Name: duration, dtype: float64

# %%
pd.unique(df["job"])
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
len(pd.unique(df["job"]))
# Out:
# 12

# %%
df2=df[df["age"]>=60]
df2
# Out:
#        age          job   marital  education default  balance housing loan  \
# 18      60      retired   married    primary      no       60     yes   no
# 32      60       admin.   married  secondary      no       39     yes  yes
# 42      60  blue-collar   married    unknown      no      104     yes   no
# 66      60      retired   married   tertiary      no      100      no   no
# 92      60       admin.   married  secondary      no      290     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 45191   75      retired  divorced   tertiary      no     3810     yes   no
# 45195   68      retired   married  secondary      no     1146      no   no
# 45204   73      retired   married  secondary      no     2850      no   no
# 45207   71      retired  divorced    primary      no     1729      no   no
# 45208   72      retired   married  secondary      no     5715      no   no
#
#         contact  day month  duration  campaign  previous
# ...

# %%
s=df["age"].value_counts()
s
# Out:
# 32    2085
# 31    1996
# 33    1972
# 34    1930
# 35    1894
#       ...
# 93       2
# 90       2
# 95       2
# 88       2
# 94       1
# Name: age, Length: 77, dtype: int64

# %%
s=df["job"].value_counts()
s
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1578
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64

# %%
df["job"].value_counts().sort_values(ascending=True)
# Out:
# unknown           288
# student           938
# housemaid        1240
# unemployed       1303
# entrepreneur     1487
# self-employed    1578
# retired          2264
# services         4154
# admin.           5171
# technician       7597
# management       9458
# blue-collar      9732
# Name: job, dtype: int64

# %%
s=df["contact"].value_counts()
s
# Out:
# cellular     29284
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64

# %%
pd.unique(df["education"])
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
s=df["education"].value_counts()
s
# Out:
# secondary    23201
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64

# %%
pd.unique(df["campaign"])
# Out:
# array([ 1,  2,  3,  5,  4,  6,  7,  8,  9, 10, 11, 12, 13, 19, 14, 24, 16,
#        32, 18, 22, 15, 17, 25, 21, 43, 51, 63, 41, 26, 28, 55, 50, 38, 23,
#        20, 29, 31, 37, 30, 46, 27, 58, 33, 35, 34, 36, 39, 44])

# %%
s=df["education"].value_counts()
print(s)
# Out:
# secondary    23201
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
fig=plt.figure(figsize=(15,5))
x=list(pd.unique(df["job"]))
y=list(df["job"].value_counts())
plt.barh(x,y)
plt.show()

# %%
plt.pie(y, labels=x,textprops={'fontsize': 15} ,autopct='%.1f%%',radius=3,shadow=True)
plt.title("jobs")
plt.show()
plt.figure("my fig")

# %%
fig=plt.figure(figsize=(20,5))
x=list(pd.unique(df["job"]+"  "+df["education"]))
y=list((df["job"]+"  "+df["education"]).value_counts())
plt.scatter(y,x)
plt.show()

# %%
#fig=plt.figure(figsize=(15,20))
x=list(pd.unique(df['marital']))
y=list((df['marital'].value_counts()))
plt.bar(x,y)
plt.show()

# %%
df1=df[df["balance"] <= 0]
df1
# Out:
#        age          job  marital  education default  balance housing loan  \
# 19      33     services  married  secondary      no        0     yes   no
# 24      40      retired  married    primary      no        0     yes  yes
# 25      44       admin.  married  secondary      no     -372     yes   no
# 28      46   management   single  secondary      no     -246     yes   no
# 33      59  blue-collar  married  secondary      no        0     yes   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 45038   43   unemployed  married   tertiary      no        0      no   no
# 45131   47   management  married   tertiary      no        0      no   no
# 45134   70      retired  married  secondary      no        0      no   no
# 45157   52   technician  married   tertiary      no        0      no   no
# 45160   35   technician  married  secondary      no        0     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
b=df1["balance"].count()
print(b)
# Out:
# 7280

# %%
t=df["balance"].count()
p=(b/t)*100 #percentage
print("people with balance less than or equal to 0 are: ",p)
# Out:
# people with balance less than or equal to 0 are:  16.022649355245406

# %%
df1=df[df["loan"] == "yes"]
b=df1["loan"].count()
print(b)
# Out:
# 7244

# %%
fig=plt.figure(figsize=(20,5))
s=df.plot.scatter("age","balance")
plt.show()

# %%
x=df["balance"]
y=df["age"]
plt.scatter(y,x)
plt.show()
